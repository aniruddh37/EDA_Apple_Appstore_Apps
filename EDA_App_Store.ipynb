# %% [markdown]
# # 1.0 EDA of Apple AppStore Apps
# - Author: Aniruddh Pal
# - Email: aniruddhpal144@gmail.com

# %% [markdown]
# # 2.0 Description
# - Data: Apple AppStore Apps
# - **Dataset:** 🔗 [*link*](https://www.kaggle.com/datasets/gauthamp10/apple-appstore-apps)
#
# __Context__
# - Apple AppStore Android App Data. (1.2 Million+ App Data)
#
# __Content__
# - The data was collected with the help of Python script (Scrapy) running on a cluster of cloud vm instances.
# -The data was collected in the month of October 2021.
#
# ## 2.1 Task:
# We intend to conduct an Exploratory Data Analysis (EDA) on the given dataset. The EDA will serve as the basis for the necessary Data Wrangling activities to be carried out for the purposes of Data Cleaning and Normalization. During the coding process, we will document our observations. Ultimately, we will produce a summary and draw conclusions from our findings.
#
# ## 2.2 Objectives:
# The primary aim of this project is to conduct a thorough analysis of the dataset to identify significant insights. The ultimate goal is to project and emphasize customer dynamics and demands to developers and other relevant stakeholders. This will assist in driving more business towards their upcoming applications.

# %% [markdown]
# ## 3.0 *Import Libraries*:
# - We will use the following libraries:
#     1. Pandas: Data manipulation and analysis library.
#     2. NumPy: Numerical computing library.
#     3. Matplotlib: Data visualization library.
#     4. Seaborn: Statistical data visualization library.
#     5. Scipy: To provide a comprehensive set of numerical algorithms and tools for scientific computing in Python.

# %%
# Import Libraries
import pandas as pd
import numpy as np

# Visualization Libraries
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# For Scientific and Statistical computing
import scipy as sp

# %% [markdown]
# ## 4.0 Data Loading, Exploration and Wrangling
#
# We will proceed as follows:
# ### 4.1 Load the csv file with the pandas
#
# ### 4.2 Creating the dataframe and understanding the data present in the dataset
#
# ### 4.3 Dealing with the missing data and the incorrect records

# %%
# Load Dataset
df = pd.read_csv('/kaggle/input/apple-appstore-apps/appleAppData.csv')

# %% [markdown]
# ### 4.4 Analysing & Describing the Dataset:
#
# This code snippet helps you get a complete overview of your data by adjusting a key display setting in Pandas. By setting the option to show all columns, you can ensure that no valuable information is overlooked when working with dataframes. Whether you're exploring data, conducting analysis or simply trying to get a better sense of your data, this simple line of code can make a big difference.

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### 4.5 Get a sneak peek of your data:
# With just a single line of code! Quickly view the top rows of your dataset to get a sense of what you're working with, without having to scroll through the entire file.

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# ### 4.6 View the Column Names:

# %%
# View the Column names, alternatively we can also use df.columns
print(df.columns.values)
# Out:
# ['App_Id' 'App_Name' 'AppStore_Url' 'Primary_Genre' 'Content_Rating'
#  'Size_Bytes' 'Required_IOS_Version' 'Released' 'Updated' 'Version'
#  'Price' 'Currency' 'Free' 'DeveloperId' 'Developer' 'Developer_Url'
#  'Developer_Website' 'Average_User_Rating' 'Reviews'
#  'Current_Version_Score' 'Current_Version_Reviews']

# %% [markdown]
# ### 4.7 View the Shape of the Dataset:

# %%
# View the Shape of the dataset, number of rows & columns
print(f"The dataframe has {df.shape[0]} rows and {df.shape[1]} columns.")
# Out:
# The dataframe has 1230376 rows and 21 columns.

# %% [markdown]
# *The dataset has more than 21 columns/attributes.*

# %% [markdown]
# #### Observation Set 1:
# > Attributes Released, Updated are date & time data type in UTC format.
#
# - The 'T' doesn’t really stand for anything. It is just the separator that the ISO 8601 combined date-time format requires. You can read it as an abbreviation for Time.
# - The 'Z' stands for the Zero timezone, as it is offset by 0 from the Coordinated Universal Time (UTC).
#
# > Column Names Are:
#
# *'App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#  'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#  'Price', 'Currency', 'Free', 'DeveloperId', 'Developer', 'Developer_Url',
#  'Developer_Website', 'Average_User_Rating', 'Reviews',
#  'Current_Version_Score', 'Current_Version_Reviews'*

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 21 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %% [markdown]
# ### 4.8 Descriptive Statistics
# We use descriptive statistics to summarize and understand the key features of dataset.

# %%
df.describe()
# Out:
#          Size_Bytes         Price   DeveloperId  Average_User_Rating  \
# count  1.230152e+06  1.229886e+06  1.230376e+06         1.230376e+06
# mean   7.510857e+07  5.041264e-01  1.092869e+09         1.788387e+00
# std    2.318726e+08  6.869674e+00  4.090897e+08         2.154105e+00
# min    2.762800e+04  0.000000e+00  2.816565e+08         0.000000e+00
# 25%    2.041344e+07  0.000000e+00  7.381109e+08         0.000000e+00
# 50%    4.333158e+07  0.000000e+00  1.179711e+09         0.000000e+00
# 75%    8.365466e+07  0.000000e+00  1.471960e+09         4.333330e+00
# max    7.677945e+10  9.999900e+02  1.590233e+09         5.000000e+00
#
#             Reviews  Current_Version_Score  Current_Version_Reviews
# count  1.230376e+06           1.230376e+06             1.230376e+06
# mean   8.259478e+02           1.788387e+00             8.259478e+02
# std    5.016051e+04           2.154105e+00             5.016051e+04
# min    0.000000e+00           0.000000e+00             0.000000e+00
# ...

# %% [markdown]
# #### Observation Set 2:
# 1. We have 7 numeric columns in the original dataset.
# 2. Column Size_bytes contains data in Bytes. --> We will add one column to hold the size_bytes data in MB format.

# %% [markdown]
# ### 4.9 Missing values in the Data:

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Website          643988
# Developer_Url                1109
# Price                         490
# Size_Bytes                    224
# Released                        3
# App_Name                        1
# Free                            0
# Current_Version_Score           0
# Reviews                         0
# Average_User_Rating             0
# Developer                       0
# DeveloperId                     0
# App_Id                          0
# Currency                        0
# Version                         0
# Updated                         0
# Required_IOS_Version            0
# Content_Rating                  0
# Primary_Genre                   0
# AppStore_Url                    0
# Current_Version_Reviews         0
# dtype: int64

# %% [markdown]
# ## 5.0 **Exploratory Data Analysis and Visualization:**

# %%
# Heatmap to visualize the missing values
plt.rcParams['figure.figsize'] = (15, 6)
sns.heatmap(df.isnull(), yticklabels = False, cbar = False, cmap = 'viridis')
plt.title("Missing Null Values") 
plt.show()

# %% [markdown]
# > **Figure-1:** Provide us the visual on the missing values in a dataframe 'df'.

# %% [markdown]
# #### Get a clearer picture of missing data with this nifty code snippet! See the percentage of null values in your dataset sorted in ascending order, making it easy to identify which features have the most missing data.

# %%
# Percentage of Missing Values of Dataset in Sorted List
#df.isnull().sum()/len(df)*100
missing_percentage = (df.isnull().sum().sort_values(ascending = False) / len(df)) * 100
missing_percentage
# Out:
# Developer_Website          52.340748
# Developer_Url               0.090135
# Price                       0.039825
# Size_Bytes                  0.018206
# Released                    0.000244
# App_Name                    0.000081
# Free                        0.000000
# Current_Version_Score       0.000000
# Reviews                     0.000000
# Average_User_Rating         0.000000
# Developer                   0.000000
# DeveloperId                 0.000000
# App_Id                      0.000000
# Currency                    0.000000
# Version                     0.000000
# Updated                     0.000000
# Required_IOS_Version        0.000000
# Content_Rating              0.000000
# Primary_Genre               0.000000
# AppStore_Url                0.000000
# Current_Version_Reviews     0.000000
# dtype: float64

# %% [markdown]
# ### 5.1 We will generate a graphical representation of the percentage of null values by plotting the data using an appropriate charting technique.

# %%
# Graphical Representation of Percentage of Null Values
missing_percentage = missing_percentage[missing_percentage != 0]    # Only the missing data
plt.rcParams['figure.figsize'] = (20, 6)
missing_percentage.plot(kind = 'barh')
plt.title("Percentage of Null Values")
plt.show()

# %% [markdown]
# > **Figure-2:** It is obvious that due to high presence of null values inside Developer Website column, all other null values are not visible.

# %% [markdown]
# #### Observation Set 3:
#
# > Dealing with the Null Values:
#
# 1. The column having the highest percentage of null values is :\
# *Developer Website*
#
# Based on its lack of relevance and the high number of Null values associated with it, we have made the decision to drop this attribute from the dataset.

# %%
# Drop or Delete the Column(Developer Website) due to high number of Null 

df.drop('Developer_Website', axis=1, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1230376 entries, 0 to 1230375
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1230376 non-null  object
#  1   App_Name                 1230375 non-null  object
#  2   AppStore_Url             1230376 non-null  object
#  3   Primary_Genre            1230376 non-null  object
#  4   Content_Rating           1230376 non-null  object
#  5   Size_Bytes               1230152 non-null  float64
#  6   Required_IOS_Version     1230376 non-null  object
#  7   Released                 1230373 non-null  object
#  8   Updated                  1230376 non-null  object
#  9   Version                  1230376 non-null  object
#  10  Price                    1229886 non-null  float64
#  11  Currency                 1230376 non-null  object
#  12  Free                     1230376 non-null  bool
# ...

# %%
# Sorting the columns after deleting the Developing Website Column
df.isnull().sum().sort_values(ascending=False)
# Out:
# Developer_Url              1109
# Price                       490
# Size_Bytes                  224
# Released                      3
# App_Name                      1
# Free                          0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# App_Id                        0
# Currency                      0
# Version                       0
# Updated                       0
# Required_IOS_Version          0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %% [markdown]
# #### Observation Set 4:
# Price, Size_Bytes are important columns so it is good to fill the null values.

# %%
# Dealing with the Missing Values
# Filling mean values of Price Column in the null places of that column
df['Price'] = df.Price.fillna(value=df['Price'].mean())
df['Size_Bytes'] = df.Size_Bytes.fillna(value=df['Size_Bytes'].mean())

# Have a view of refreshsed dataset again
df.isnull().sum().sort_values(ascending = False)
# Out:
# Developer_Url              1109
# Released                      3
# App_Name                      1
# App_Id                        0
# Currency                      0
# Current_Version_Score         0
# Reviews                       0
# Average_User_Rating           0
# Developer                     0
# DeveloperId                   0
# Free                          0
# Price                         0
# Version                       0
# Updated                       0
# Required_IOS_Version          0
# Size_Bytes                    0
# Content_Rating                0
# Primary_Genre                 0
# AppStore_Url                  0
# Current_Version_Reviews       0
# dtype: int64

# %% [markdown]
# ### 5.2 To view only those rows where a column has null values

# %%
# To view the Released Column
df[df['Released'].isnull()].head(5)
# Out:
#                                                App_Id  \
# 264853  com.ironhidegames.frontiers.universal.premium
# 836858                    com.redgamesco.transformers
# 919513    com.crayolallc.crayola-create-and-play-plus
#
#                             App_Name  \
# 264853    Kingdom Rush Frontiers TD+
# 836858  Transformers: Tactical Arena
# 919513      Crayola Create and Play+
#
#                                              AppStore_Url Primary_Genre  \
# 264853  https://apps.apple.com/us/app/kingdom-rush-fro...         Games
# 836858  https://apps.apple.com/us/app/transformers-tac...         Games
# 919513  https://apps.apple.com/us/app/crayola-create-a...         Games
#
#        Content_Rating    Size_Bytes Required_IOS_Version Released  \
# 264853            12+  7.510857e+07                 13.0      NaN
# 836858             9+  7.510857e+07               13.5.0      NaN
# 919513             4+  7.510857e+07                   13      NaN
#
# ...

# %%
# To view the Developer_Url Column
df[df['Developer_Url'].isnull()].head(5)
# Out:
#                            App_Id         App_Name  \
# 2382              com.TroopAdmin2  C&S Troop Admin
# 2827       com.dhrubajyoti.bangla    Bangla Rhymes
# 3498  com.f1rstmotors.f1rstmotors     F1RST MOTORS
# 5820       tr.com.okuvaryum.mobil        Okuvaryum
# 5821        tr.com.okuvaryum.okul   Okuvaryum Okul
#
#                                            AppStore_Url Primary_Genre  \
# 2382  https://apps.apple.com/us/app/c-s-troop-admin/...      Business
# 2827  https://apps.apple.com/us/app/bangla-rhymes/id...     Education
# 3498  https://apps.apple.com/us/app/f1rst-motors/id1...      Business
# 5820  https://apps.apple.com/us/app/okuvaryum/id1493...     Education
# 5821  https://apps.apple.com/us/app/okuvaryum-okul/i...     Education
#
#      Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 2382             4+  87355392.0                 10.0  2021-06-04T07:00:00Z
# 2827             4+  56445952.0                  9.1  2019-03-23T18:27:49Z
# ...

# %%
# To view the App Name Column
df[df['App_Name'].isnull()].head(5)
# Out:
#                 App_Id App_Name  \
# 964888  se.promedia.NA      NaN
#
#                                              AppStore_Url Primary_Genre  \
# 964888  https://apps.apple.com/us/app/na/id449134868?uo=4          News
#
#        Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 964888             4+  19528704.0                  9.0  2011-08-08T11:45:30Z
#
#                      Updated Version  Price Currency  Free  DeveloperId  \
# 964888  2020-12-21T14:08:02Z   8.1.2    0.0      USD  True    449134871
#
#        Developer                                      Developer_Url  \
# 964888  Promedia  https://apps.apple.com/us/developer/promedia/i...
#
#         Average_User_Rating  Reviews  Current_Version_Score  \
# 964888                  5.0        1                    5.0
#
#         Current_Version_Reviews
# 964888                        1

# %% [markdown]
# 1. We can try to write a code to replace the null value in the column *app_name* by looking for same app_ID of the null row in other row with valid app_name value and sme app_ID
# 2. We can try to write a code to replace the null value in the column *Developer_Url* by looking for same app_ID of the null row in other row with valid app_name value and sme app_ID
# 3. We can try to write a code to replace the null value in the column *Released* by looking for same app_name of the null row in other row with valid app_name value and sme app_ID

# %% [markdown]
# ### 5.3 Null Handling: Filling Null Values Approach
#
# Fill null values with caution! Unique values associated with specific features, such as AppID and AppName, in rows where Released is null, can make filling null values tricky. Instead, consider dropping only those rows where Developer_URL, Released, and appName are null to ensure data integrity.

# %%
df.dropna(subset=['Developer_Url'], inplace=True)

df.dropna(subset=['Released'], inplace=True)

df.dropna(subset=['App_Name'], inplace=True)

# %%
# Have a view of refreshed dataset again
df.isnull().sum().sort_values(ascending = False)
# Out:
# App_Id                     0
# App_Name                   0
# Current_Version_Score      0
# Reviews                    0
# Average_User_Rating        0
# Developer_Url              0
# Developer                  0
# DeveloperId                0
# Free                       0
# Currency                   0
# Price                      0
# Version                    0
# Updated                    0
# Released                   0
# Required_IOS_Version       0
# Size_Bytes                 0
# Content_Rating             0
# Primary_Genre              0
# AppStore_Url               0
# Current_Version_Reviews    0
# dtype: int64

# %% [markdown]
# ### Milestone 1: We have cleaned the dataset from null values 🙂
#
# > Next, Find duplications and Analyse them if its a valid DUPLICATION

# %%
df.duplicated().any()
# Out:
# False

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews'],
#       dtype='object')

# %%
any_duplicates = df.duplicated(subset=['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
       'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
       'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
       'Developer_Url', 'Average_User_Rating', 'Reviews',
       'Current_Version_Score', 'Current_Version_Reviews']).any()

# %%
boolean = df['App_Name'].duplicated().any()
boolean
# Out:
# True

# %%
df['App_Name'].value_counts().sort_values(ascending=False)
# Out:
# App_Name
# Vanguard              6
# Linker                5
# Bloom                 5
# Currency Converter    4
# Awaken                4
#                      ..
# TwoFactor             1
# TWOTOO                1
# TwoWayStreaming       1
# TWSpeed Telecom       1
# Sổ Điểm Thông Minh    1
# Name: count, Length: 1222413, dtype: int64

# %% [markdown]
# > From the above cell output we can see that App Name column has multiple rows. Let's check out that data in those rows is identical or not.

# %%
df[df['App_Name'] == 'Linker']
# Out:
#                         App_Id App_Name  \
# 139096   com.cheerg.LinkerTest   Linker
# 462132           br.com.linker   Linker
# 745039      team.linker.linker   Linker
# 954862         com.kubo.Linker   Linker
# 1206501  com.tilon.elcloud.rdc   Linker
#
#                                               AppStore_Url     Primary_Genre  \
# 139096   https://apps.apple.com/us/app/linker/id1208886...         Lifestyle
# 462132   https://apps.apple.com/us/app/linker/id1472621...           Finance
# 745039   https://apps.apple.com/us/app/linker/id1558364...  Health & Fitness
# 954862   https://apps.apple.com/us/app/linker/id1169163...            Travel
# 1206501  https://apps.apple.com/us/app/linker/id1215552...         Utilities
#
#         Content_Rating   Size_Bytes Required_IOS_Version  \
# 139096              4+   21876736.0                 10.0
# 462132              4+  169309184.0                 12.0
# 745039              4+   97497088.0                 10.0
# ...

# %% [markdown]
# ### Milestone 2: *Hence no duplicates found* 👥
#
# Although App_Name may have duplications, the records are unique as a whole, with varying versions, App Id's, and release dates.

# %% [markdown]
# ---

# %% [markdown]
# ### 5.4 Now exploring Numeric columns/attributes of the dataset namely:
# Size_Bytes, Price, DeveloperId, Average_User_Rating, Reviews, Current_Version_Score, Current_Version_Reviews

# %%
df['Size_Bytes'].unique()
# Out:
# array([2.19934720e+07, 1.31358720e+07, 2.19432960e+07, ...,
#        1.19404544e+08, 5.96570000e+05, 5.06896000e+05])

# %%
df['Price'].unique()
# Out:
# array([0.00000000e+00, 2.99000000e+00, 1.99000000e+00, 9.90000000e-01,
#        4.99000000e+00, 9.99000000e+00, 5.99000000e+00, 6.99000000e+00,
#        1.69900000e+01, 1.99900000e+01, 3.99900000e+01, 5.99900000e+01,
#        8.99000000e+00, 7.99000000e+00, 1.89900000e+01, 3.99000000e+00,
#        2.49900000e+01, 1.49900000e+01, 2.89900000e+01, 2.19900000e+01,
#        1.39900000e+01, 1.09900000e+01, 1.19900000e+01, 1.29990000e+02,
#        2.29900000e+01, 1.39990000e+02, 2.59900000e+01, 1.29900000e+01,
#        4.99900000e+01, 2.39900000e+01, 1.19990000e+02, 7.99900000e+01,
#        1.79900000e+01, 4.99990000e+02, 2.49990000e+02, 1.99990000e+02,
#        2.29990000e+02, 3.49900000e+01, 2.09900000e+01, 9.99900000e+01,
#        3.39900000e+01, 5.49900000e+01, 4.59900000e+01, 4.49900000e+01,
#        2.99900000e+01, 6.99900000e+01, 2.79900000e+01, 8.49900000e+01,
#        6.49900000e+01, 1.59900000e+01, 2.69900000e+01, 3.59900000e+01,
# ...

# %%
df['Average_User_Rating'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 4.00352, 3.91608, 4.82733])

# %%
df['Reviews'].unique()
# Out:
# array([    0,     1,  1285, ..., 12691, 35476, 10481])

# %%
df['Current_Version_Score'].unique()
# Out:
# array([0.     , 5.     , 4.78132, ..., 4.00352, 3.91608, 4.82733])

# %%
df['Currency'].unique()
# Out:
# array(['USD'], dtype=object)

# %% [markdown]
# > The currency used is standard US Dollar 💵💵💵 across the dataset.

# %%
df['Content_Rating'].unique()
# Out:
# array(['4+', '17+', '9+', '12+', 'Not yet rated'], dtype=object)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# ### 5.5 Adding column to hold Size_Bytes in MBs

# %%
df['Size_MB'] = 0

# %%
df.columns
# Out:
# Index(['App_Id', 'App_Name', 'AppStore_Url', 'Primary_Genre', 'Content_Rating',
#        'Size_Bytes', 'Required_IOS_Version', 'Released', 'Updated', 'Version',
#        'Price', 'Currency', 'Free', 'DeveloperId', 'Developer',
#        'Developer_Url', 'Average_User_Rating', 'Reviews',
#        'Current_Version_Score', 'Current_Version_Reviews', 'Size_MB'],
#       dtype='object')

# %% [markdown]
# #### 5.5.1 Conversion of Size_Bytes in MBs
# - First we will convert Size_Bytes data to KB and then to MB

# %%
df['Size_MB'] = df['Size_Bytes'].apply(lambda x: (float(x) / 1024) / 1024)

# %%
df.Average_User_Rating.describe()
# Out:
# count    1.229263e+06
# mean     1.788848e+00
# std      2.154179e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      4.333330e+00
# max      5.000000e+00
# Name: Average_User_Rating, dtype: float64

# %% [markdown]
# ### 5.6 Creating the column type for Free and Paid Apps
# Using the Free column, it's helpful while dealing with the Paid and Free Apps form data readability perspective 🤓

# %%
df['Type'] = np.where(df['Free'] == True, 'Free', 'Paid')
df.drop(['Free'], axis=1, inplace=True)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0             4+  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.Reviews.describe()
# Out:
# count    1.229263e+06
# mean     8.266250e+02
# std      5.018320e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.000000e+00
# max      2.268533e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# ### 5.7 Viewing the content of the column 'Content_Rating'
# - First we will view the unique values present in this column

# %%
for i in df.Content_Rating.unique():
    print(i)
# Out:
# 4+
# 17+
# 9+
# 12+
# Not yet rated

# %% [markdown]
# #### Observation Set 6:
# 1. We have various Categories in the Content Rating column:
# - 4+
# - 17+
# - 9+
# - 12+
# - Not yet rated
#
# Now, we makes these categories to a simple 5 readable Categories for better understanding:
#
# - 4+ : Kids
# - 17+ : Adults
# - 9+ : Children
# - 12+ : Teens
# - Not yet rated : Everyone

# %%
df["Content_Rating"] = df["Content_Rating"].replace("4+", "Kids")
df["Content_Rating"] = df["Content_Rating"].replace("9+", "Children")
df["Content_Rating"] = df["Content_Rating"].replace("12+", "Teen")
df["Content_Rating"] = df["Content_Rating"].replace("17+", "Adults")
df["Content_Rating"] = df["Content_Rating"].replace("Not yet rated","Everyone")

# %% [markdown]
# - Presenting the content of the column in Ascending order 'Kids', 'Children', 'Teens', 'Everyone', 'Adults'

# %%
agegroup = df['Content_Rating'].unique()

# Define the order in which you want to print the values
Custom_order = ['Kids', 'Children', 'Teens', 'Everyone', 'Adults']

# Sort the array in the Custom Order
sorted_array = sorted(['Kids', 'Children', 'Adults', 'Teens', 'Everyone'], key=lambda x: Custom_order.index(x))

# Print the Sorted Array
print(sorted_array)
# Out:
# ['Kids', 'Children', 'Teens', 'Everyone', 'Adults']

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0           Kids  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %% [markdown]
# ### 5.8 Let's change the Reviews to certain ranges for the better understanding of the data

# %%
df.Reviews.min()
# Out:
# 0

# %%
df.Reviews.max()
# Out:
# 22685334

# %%
df.Reviews.describe()
# Out:
# count    1.229263e+06
# mean     8.266250e+02
# std      5.018320e+04
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      3.000000e+00
# max      2.268533e+07
# Name: Reviews, dtype: float64

# %% [markdown]
# #### Observation Set 7:
# Review column is numeric column that holds information about the number of reviews users left while dowloading / using the app.
# > We have a long sequence of data when it comes to  Reviews column:
#
# min:      0\
# max:     22685334
#
# We can club this long sequence into a compressed form and presentation. In another column called ReviewCategory.
#
# - If an app has reviews between 0 and 10000 --> Less than 10K
# - If an app has reviews between 10000 and 500000 --> Between 10K and 500K
# - If an app has reviews between 500000 and 1000000 --> Between 500K and 1Mil
# - If an app has reviews between 1000000 and 22685334 --> Million Plus

# %%
df['ReviewCategory'] = 'NoReviewsProvided'
df.loc[(df['Reviews'] > 0) & (df['Reviews'] <= 10000.0),'ReviewCategory'] = 'Less than 10K'
df.loc[(df['Reviews'] > 10000) & (df['Reviews'] <= 500000.0),'ReviewCategory'] = 'Between 10K and 500K'
df.loc[(df['Reviews'] > 500000) & (df['Reviews'] <= 1000000),'ReviewCategory'] = 'Between 500K and 1Mil'
df.loc[(df['Reviews'] > 1000000) & (df['Reviews'] <= 22685334),'ReviewCategory'] = 'Million Plus'
df['ReviewCategory'].value_counts()
# Out:
# ReviewCategory
# NoReviewsProvided        683549
# Less than 10K            538691
# Between 10K and 500K       6725
# Million Plus                152
# Between 500K and 1Mil       146
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1229263 entries, 0 to 1230375
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count    Dtype
# ---  ------                   --------------    -----
#  0   App_Id                   1229263 non-null  object
#  1   App_Name                 1229263 non-null  object
#  2   AppStore_Url             1229263 non-null  object
#  3   Primary_Genre            1229263 non-null  object
#  4   Content_Rating           1229263 non-null  object
#  5   Size_Bytes               1229263 non-null  float64
#  6   Required_IOS_Version     1229263 non-null  object
#  7   Released                 1229263 non-null  object
#  8   Updated                  1229263 non-null  object
#  9   Version                  1229263 non-null  object
#  10  Price                    1229263 non-null  float64
#  11  Currency                 1229263 non-null  object
#  12  DeveloperId              1229263 non-null  int64
# ...

# %% [markdown]
# ### 5.9 Cleaning Average_User_Rating column:
# Let's round off and store the float decimal values in the df.Average_User_Rating column, which are currently in the range of 0 0to 5.

# %%
df['Average_User_Rating'] = df['Average_User_Rating'].round().astype(int)

# %%
df.head(5)
# Out:
#                              App_Id                 App_Name  \
# 0               com.hkbu.arc.apaper           A+ Paper Guide
# 1               com.dmitriev.abooks                  A-Books
# 2                    no.terp.abooks                  A-books
# 3          fr.antoinettefleur.Book1              A-F Book #1
# 4  com.imonstersoft.azdictionaryios  A-Z Synonyms Dictionary
#
#                                         AppStore_Url Primary_Genre  \
# 0  https://apps.apple.com/us/app/a-paper-guide/id...     Education
# 1  https://apps.apple.com/us/app/a-books/id103157...          Book
# 2  https://apps.apple.com/us/app/a-books/id145702...          Book
# 3  https://apps.apple.com/us/app/a-f-book-1/id500...          Book
# 4  https://apps.apple.com/us/app/a-z-synonyms-dic...     Reference
#
#   Content_Rating  Size_Bytes Required_IOS_Version              Released  \
# 0           Kids  21993472.0                  8.0  2017-09-28T03:02:41Z
# ...

# %%
df.Average_User_Rating.unique()
# Out:
# array([0, 5, 3, 4, 2, 1])

# %% [markdown]
# # 6.0 Question and Answers:
# > We are going to pose following questions against the dataset:
#
# 1. What are the top 10 Categories that are installed from the Apple App Store?
# 2. What are the highest top 10 rated Primary_Genre based on Average_User_Rating?
# 3. Which Primary_Genre has the highest count of Paid and Free apps?
# 4. What are the top 5 Paid Apps based with highest Ratings?
# 5. What are the top 5 Free Apps based with highest Ratings?
# 6. What are the top 10 most Reviewed Apps (Unique)?
# 7. What are the top 10 Game Apps based on Reviews on the Apple App Store?
# 8. What are the top 10 Bussiness Apps based on Reviews on the Apple App Store?
# 9. What are the top 10 Education Apps based on Reviews on the Apple App Store?
# 10. What are the top 10 Social Networking Apps based on Reviews on the Apple App Store?
# 11. What are the Apps with highest Content_Rating?
# 12. Years in which Maximum Apps were Released?
# 13. Size in MB's Vs Price of App.
# 14. What are the top 10 Apps producing Developers?
# 15. Which type of Genre attracted what kind of clients in terms of revenue?
# 16. YoY (Year on Year) comparison of Apps per Content_Rating.
# 17. User_Rating Vs Price.
# 18. User_Rating Vs MBytes.
# 19. What are the Best App of Year?
# 20. YoY (Year on Year) break down of top 5 Genre based on App Price.
# 21. What are the top Rated Apps in each Category?
# 22. What are the top Categories by App Count?
# 23. What should be ideal Size of an App?
# 24. IOS Versions Vs Count of App.
# 25. Interdependency of numeric attributes on each other.

# %% [markdown]
# ---

# %% [markdown]
# **Question 1:** What are the top 10 Categories that are installed from the Apple App Store?

# %%
top_Genre = df.Primary_Genre.value_counts().reset_index().rename(columns={'Primary_Genre' : 'Count', 'index' : 'Primary_Genre'})

# %%
top10_top_Genre = top_Genre.head(10)

# %%
top10_top_Genre.head(10)
# Out:
#               Count   count
# 0             Games  193641
# 1          Business  128203
# 2         Education  119114
# 3         Utilities   93937
# 4         Lifestyle   84493
# 5      Food & Drink   72815
# 6  Health & Fitness   60682
# 7      Productivity   59389
# 8     Entertainment   53076
# 9          Shopping   49493

# %%
sns.barplot(data=top10_top_Genre, x='Count', y='count', color='blue')
plt.xticks(rotation=45)
plt.title('Top 10 Categories Installed from Apple App Store')
plt.show()

# %% [markdown]
# > **Figure-3:** Shows the Top 10 Categories that are installed from the Apple App Store.

# %% [markdown]
# - **Answer 1:** Gaming Apps are the most downloaded apps from the Apple App Store.

# %% [markdown]
# ---

# %% [markdown]
# **Question 2:** What are the highest top 10 rated Primary_Genre based on Average_User_Rating?

# %%
# Group the Dataset by Primary_Genre and Calculate the mean of Average_User_Rating from each group
mean_ratings = df.groupby('Primary_Genre')['Average_User_Rating'].mean()

# Sort the Result Series in the descending order
sorted_ratings = mean_ratings.sort_values(ascending=False)

# Select the top 10 Entries
top_10 = sorted_ratings.head(10)
print(top_10)
# Out:
# Primary_Genre
# Weather              2.622647
# Games                2.566197
# Photo & Video        2.316027
# Music                2.264037
# Book                 2.194122
# Reference            2.191638
# Finance              2.133502
# Entertainment        2.026566
# Social Networking    1.999213
# Health & Fitness     1.859003
# Name: Average_User_Rating, dtype: float64

# %% [markdown]
# - **Answer 2:** Based on Average_User_Rating the highest top 10 Rated pimary_genre are Weather, Games, Photo & Video, Music, Book, Reference, Finance, Entertainment, Social Networking, Health & Fitness.

# %% [markdown]
# ---

# %% [markdown]
# **Question 3:** Which Primary_Genre has the highest count of Paid and Free apps?

# %%
# Group the dataset by Primary_Genre and Type, and Count the Number of Apps in each group
genre_counts = df.groupby(['Primary_Genre', 'Type']).size().reset_index(name='Count')
# Separate the Free Apps
top10_free_apps = genre_counts[genre_counts['Type'] == 'Free']
# Load the top 10 Free Apps
top_10_free_genres = top10_free_apps.sort_values(by='Count', ascending=False).head(10)
# top_10_free_genres

# %%
# Print the top 5 Free Genres
top_10_free_genres.head(5)
# Out:
#    Primary_Genre  Type   Count
# 14         Games  Free  177305
# 2       Business  Free  125443
# 6      Education  Free  101740
# 48     Utilities  Free   84217
# 20     Lifestyle  Free   81223

# %%
# Separate the Paid Apps
top10_paid_apps = genre_counts[genre_counts['Type'] == 'Paid']
# Load the Paid Apps 
top_10_paid_genres = top10_paid_apps.sort_values(by='Count', ascending=False).head(10)
# top_10_paid_genres

# %%
# Print the top 5 Paid Genres
top_10_paid_genres.head(5)
# Out:
#    Primary_Genre  Type  Count
# 7      Education  Paid  17374
# 15         Games  Paid  16336
# 49     Utilities  Paid   9720
# 45      Stickers  Paid   8865
# 35  Productivity  Paid   6002

# %% [markdown]
# - **Answer 3:**
#     > **Free Apps Genre List:** Games, Bussiness, Education, Utilities, Lifestyle.
#
#     > **Paid Apps Genre List:** Education, Games, Utilities, Stickers, Productivity.

# %% [markdown]
# ---

# %% [markdown]
# **Question 4:** What are the top 5 Paid Apps based with highest Ratings?

# %%
# Sort the Paid Apps by Rating in descending order and Select the Top 5
top5_paid_apps = df[df['Type'] == 'Paid'].sort_values('Average_User_Rating', ascending=False).head(5)[['App_Name', 'Average_User_Rating']]

# Display the top 5 Paid Apps and their Ratings
print(top5_paid_apps)
# Out:
#                             App_Name  Average_User_Rating
# 545133             Super Nano Trucks                    5
# 186395             FarRock Dodgeball                    5
# 466479  Money Easy - Expense Tracker                    5
# 466486  Money Flow - Expense Tracker                    5
# 466487                  Sketch Ideas                    5

# %% [markdown]
# - **Answer 4:** The top 5 Paid Apps with highest Ratings are AA Big Book and More, Gabe and the Pesky Bug, Aakkospeli Lapsille, F&P Prompting Guide 1, Animal Fun for Toddlers & Kids.

# %% [markdown]
# ---

# %% [markdown]
# **Question 5:** What are the top 5 Free Apps based with highest Ratings?

# %%
# Sort the Free Apps by Rating in descending order and Select the Top 5
top5_free_apps = df[df['Type'] == 'Free'].sort_values('Average_User_Rating', ascending=False).head(5)[['App_Name', 'Average_User_Rating']]

# Display the Top 5 Free Apps and their Ratings
print(top5_free_apps)
# Out:
#                               App_Name  Average_User_Rating
# 403942   Rise of Zombie - City Defense                    5
# 1102121                Dog Wheelchairs                    5
# 1102118        Dog App - Breed Scanner                    5
# 223230                    Dojo Login 2                    5
# 223229                       Dojo Hero                    5

# %% [markdown]
# - **Answer 5:** The top 5 Free Apps based with highest Ratings are AAB Mobile, Sát hạch lái xe ôtô, São Judas - Chama Aqui!, Aalisiri Audiobooks, Aarti Bhajan Chalisa Sangrah.

# %% [markdown]
# ---

# %% [markdown]
# **Question 6:** What are the top 10 most Reviewed Apps (Unique)?

# %% [markdown]
# - We group the Apps by Name and pick the one with the Highest Number of Reviews, ensuring each app appears only once.

# %%
# Drop duplicate App Names, Keeping the one with Highest Reviews
top_reviewed = df.sort_values('Reviews', ascending=False).drop_duplicates(subset='App_Name')

# Select the Top 10 Apps by Reviews
top_10_reviewed = top_reviewed[['App_Name', 'Reviews', 'Average_User_Rating']].head(10)
print("Top 10 Apps by Reviews:")
print(top_10_reviewed)
# Out:
# Top 10 Apps by Reviews:
#                                App_Name   Reviews  Average_User_Rating
# 415817   YouTube: Watch, Listen, Stream  22685334                    5
# 996310                        Instagram  21839585                    5
# 647929   Spotify New Music and Podcasts  18893225                    5
# 483342                            Venmo  12634191                    5
# 580482         DoorDash - Food Delivery  12517538                    5
# 456470                           TikTok  10598509                    5
# 961751                             Lyft  10241777                    5
# 1136477              WhatsApp Messenger   9090956                    5
# 933632        Pandora: Music & Podcasts   8297798                    5
# 22346                             Bible   7181127                    5

# %%
# Create a Barplot to Show the Top 10 Most Reviewed Apps 
plt.figure(figsize=(12, 6))
sns.barplot(data=top_10_reviewed, x='App_Name', y='Reviews', color='blue')
plt.xticks(rotation=45, ha='right')
plt.title('Top 10 Most Reviewed Apps')
plt.ylabel('Number of Reviews')
plt.xlabel('Apps Name')
plt.tight_layout()
plt.show()

# %% [markdown]
# > **Figure-4:** Shows the Top 10 Most Reviewed Apps on Apple App Store.

# %% [markdown]
# - **Answer 6:** The top 10 Most Reviewed Apps on the Apple App Store are YouTube, Instagram, Spotify New Music and Podcasts, Venmo, DoorDash - Food Delivery, TikTok, Lyft, WhatsApp Messenger, Pandora: Music & Podcasts, Bible.

# %% [markdown]
# ---

# %% [markdown]
# **Question 7:** What are the top 10 Game Apps based on Reviews on the Apple App Store?

# %%
# Top 10 Game Apps based on Reviews
top_10_game_apps = df[['App_Name', 'Primary_Genre', 'Reviews']].loc[df['Primary_Genre'] == 'Games'].sort_values(by='Reviews', ascending=False).reset_index(drop=True).head(10)
top_10_game_apps
# Out:
#                          App_Name Primary_Genre  Reviews
# 0                          Roblox         Games  6127588
# 1   Sniper 3D: Gun Shooting Games         Games  2538582
# 2     Episode - Choose Your Story         Games  2334130
# 3                Candy Crush Saga         Games  2177394
# 4                      Toon Blast         Games  2119062
# 5  Happy Color® – Paint by Number         Games  2020726
# 6                      Golf Clash         Games  1887985
# 7                         Hole.io         Games  1887798
# 8                    Clash Royale         Games  1842876
# 9   Bowmasters - Multiplayer Game         Games  1830342

# %%
# Create a Bar Plot to Show the Top 10 Game Apps based on Reviews
plt.figure(figsize=(8, 4))
plt.title('Top 10 Game Apps Based on Reviews')
sns.set_theme(style = 'whitegrid')
sns.barplot(x=top_10_game_apps['Reviews'], y=top_10_game_apps['App_Name'])
# Show the plot with different colors for each bar
sns.barplot(x=top_10_game_apps['Reviews'], y=top_10_game_apps['App_Name'], palette="tab10")
plt.show()

# %% [markdown]
# > **Figure-5:** Show the Top 10 Game Apps Based on Reviews.

# %% [markdown]
# - **Answer 7:** The top 10 Game Apps based on Reviews on the Apple App Store are Roblox, Sniper 3D: Gun Shooting Games, Episode - Choose Your Story, Candy Crush Saga, Toon Blast, Happy Color® – Paint by Number, Golf Clash, Hole.io, Clash Royale, Bowmasters - Multiplayer Game.

# %% [markdown]
# ---

# %% [markdown]
# **Question 8:** What are the top 10 Bussiness Apps based on Reviews on the Apple App Store?

# %%
# Top 10 Bussiness Apps based on Reviews
top_10_business_apps = df[['App_Name', 'Primary_Genre', 'Reviews']].loc[df['Primary_Genre'] == 'Business'].sort_values(by='Reviews', ascending=False).reset_index(drop=True).head(10)
top_10_business_apps
# Out:
#                          App_Name Primary_Genre  Reviews
# 0             ZOOM Cloud Meetings      Business  2040151
# 1               Indeed Job Search      Business  1948402
# 2            ADP Mobile Solutions      Business  1945272
# 3                 Microsoft Teams      Business  1847338
# 4               DoorDash - Driver      Business  1295034
# 5                      SAP Concur      Business   870699
# 6  Scanner App: PDF Document Scan      Business   797057
# 7   Adobe Scan: PDF Scanner & OCR      Business   780382
# 8  Genius Scan - Document Scanner      Business   728252
# 9                    USPS Mobile®      Business   713294

# %%
# Create a Bar Plot to Show the Top 10 Bussiness Apps based on Reviews
plt.figure(figsize=(8, 4))
plt.title("Top 10 Bussiness Apps Based on Reviews")
sns.set_theme(style='whitegrid')
sns.barplot(x=top_10_business_apps['Reviews'], y=top_10_business_apps['App_Name'])
sns.barplot(x=top_10_business_apps['Reviews'], y=top_10_business_apps['App_Name'], palette='tab10')
# Use a Color Pallete to Assign the different Colors to Each Bar
sns.barplot(x=top_10_business_apps['Reviews'], y=top_10_business_apps['App_Name'], palette='tab10')
plt.show()

# %% [markdown]
# > **Figure-6:** Show the Top 10 Business Apps Based on Reviews.

# %% [markdown]
# - **Answer 8:** The top 10 Business Apps based on Reviews on the Apple App Store are ZOOM Cloud Meetings, Indeed Job Search, ADP Mobile Solutions, Microsoft Teams, DoorDash - Driver, SAP Concur, Scanner App: PDF Document Scan, Adobe Scan: PDF Scanner & OCR, Genius Scan - Document Scanner, USPS Mobile®.

# %% [markdown]
# ---

# %% [markdown]
# **Question 9:** What are the top 10 Education Apps based on Reviews on the Apple App Store?

# %%
# Top 10 Education Apps based on Reviews
top_10_education_apps = df[['App_Name', 'Primary_Genre', 'Reviews']].loc[df['Primary_Genre'] == 'Education'].sort_values(by='Reviews', ascending=False).reset_index(drop=True).head(10)
top_10_education_apps
# Out:
#                          App_Name Primary_Genre  Reviews
# 0                  Canvas Student     Education  2147317
# 1                Google Classroom     Education  2113858
# 2                       ClassDojo     Education  1889365
# 3     Duolingo - Language Lessons     Education  1246520
# 4    Remind: School Communication     Education  1009309
# 5                    ABCmouse.com     Education   599236
# 6  Quizlet: Learn with Flashcards     Education   527661
# 7  PictureThis - Plant Identifier     Education   502630
# 8                       Photomath     Education   491503
# 9    Epic - Kids' Books & Reading     Education   451933

# %%
# Create a Bar Plot to Show the Top 10 Education Apps based on Reviews
plt.figure(figsize=(8, 4))
plt.title('Top 10 Education Apps Based on Reviews')
sns.set_theme(style='whitegrid')
sns.barplot(x=top_10_education_apps['Reviews'], y=top_10_education_apps['App_Name'])
# Use a Color palette to assign different Colors to Each Bar
sns.barplot(x=top_10_education_apps['Reviews'], y=top_10_education_apps['App_Name'], palette='tab10')
plt.show()

# %% [markdown]
# > **Figure-7:** Show the Top 10 Education Apps Based on Reviews.

# %% [markdown]
# - **Answer 9:** The top 10 Education Apps based on Reviews on the Apple App Store are Canvas Student, Google Classroom, ClassDojo, Duolingo - Language Lessons, Remind: School Communication, ABCmouse.com, Quizlet: Learn with Flashcards, PictureThis - Plant Identifier, Photomath, Epic - Kids' Books & Reading.

# %% [markdown]
# ---

# %% [markdown]
# **Question 10:** What are the top 10 Social Networking Apps based on Reviews on the Apple App Store?

# %%
# Top 10 Social Networking Apps based on Reviews
top_10_social_networking_apps = df[['App_Name', 'Primary_Genre', 'Reviews']].loc[df['Primary_Genre'] == 
'Social Networking'].sort_values(by='Reviews', ascending=False).reset_index(drop=True).head(10)
top_10_social_networking_apps
# Out:
#                          App_Name      Primary_Genre  Reviews
# 0              WhatsApp Messenger  Social Networking  9090956
# 1      Marco Polo - Stay in Touch  Social Networking  1903982
# 2  Discord - Talk, Chat & Hangout  Social Networking  1816136
# 3                         GroupMe  Social Networking  1559725
# 4                      Google Duo  Social Networking  1377443
# 5           Plenty of Fish Dating  Social Networking  1360663
# 6                        Facebook  Social Networking  1140856
# 7                       Clubhouse  Social Networking   634681
# 8         Hoop - Make new friends  Social Networking   623216
# 9  Life360: Find Family & Friends  Social Networking   455646

# %%
# Create a Bar Plot to Show the Top 10 Social Networking Apps Based on Reviews
plt.figure(figsize=(8, 4))
plt.title('Top 10 Social Networking Apps Based on Reviews')
sns.set_theme(style='whitegrid')
sns.barplot(x=top_10_social_networking_apps['Reviews'], y=top_10_social_networking_apps['App_Name'])
# Use a Color Pallete to Assigne the different Colors to Each Bar
sns.barplot(x=top_10_social_networking_apps['Reviews'], y=top_10_social_networking_apps['App_Name'], palette='tab10')
plt.show()

# %% [markdown]
# > **Figure-8:** Show the Top 10 Social Networking Apps Based on Reviews

# %% [markdown]
# - **Answer 10:** The top 10 Social Networking Apps based on Reviews on the Apple App Store are WhatsApp Messenger, Marco Polo - Stay in Touch, Discord - Talk, Chat & Hangout, GroupMe, Google Duo, Plenty of Fish Dating, Facebook, Clubhouse, Hoop - Make new friends, Life360: Find Family & Friends.

# %% [markdown]
# ---

# %% [markdown]
# **Question 11:** What are the Apps with highest Content_Rating?

# %%
# Apps with Highest Content Rating
lst_Content_Rating = df.Content_Rating.value_counts().reset_index().rename(columns={'Content_Rating': 'Count', 'index': 'Content_Rating'})
lst_Content_Rating.sort_values(by='Count', ascending=False)
# Out:
#       Count   count
# 2      Teen   89497
# 0      Kids  980095
# 4  Everyone      10
# 3  Children   35673
# 1    Adults  123988

# %% [markdown]
# - **Answer 11:** The apps with the highest Content Rating are for Kids, Children, Adults, Teens and Everyone, with a breakdown based on the count of apps under each category.

# %% [markdown]
# ---

# %% [markdown]
# **Question 12:** Years in which Maximum Apps were Released?

# %%
# Maximum Apps were Released in which year
df['Released'] = pd.to_datetime(df['Released'])     # Convert to date-time format
df['Year_Release'] = df['Released'].dt.strftime('%Y')
cnt_year_app_Release = df.groupby(['Year_Release']).size().reset_index(name='Count')
cnt_year_app_Release.head(20).sort_values(by='Count', ascending=False)
# Out:
#    Year_Release   Count
# 12         2020  227613
# 13         2021  217823
# 11         2019  165718
# 10         2018  134744
# 9          2017  126285
# 8          2016  120304
# 7          2015   78622
# 6          2014   55305
# 5          2013   39413
# 4          2012   27937
# 3          2011   19466
# 2          2010   10942
# 1          2009    4381
# 0          2008     652
# 14         2022      58

# %%
# Create a Bar Plot to show the Yearly App Released
sns.barplot(cnt_year_app_Release, x='Year_Release', y='Count', color='blue')
plt.xticks(rotation=45)
plt.title('Yearly App Released')
plt.show()

# %% [markdown]
# > **Figure-9:** Show the Maximum Number of Apps were Released on the Apple App Store in the year 2020.

# %% [markdown]
# - **Answer 12:** In 2020, the Apple App Store saw the highest number of apps released, likely due to COVID-19 pandemic forcing more people to stay at home during lockdowns.

# %% [markdown]
# ---

# %% [markdown]
# **Question 13:** Size in MB's Vs Price of App.

# %%
# Group the Dataset by Primary_Genre and Type, and Count the Number of Apps in each group
Tot_Apps_Size_Price = df.groupby(['Size_MB', 'Price']).size().reset_index(name='Count')

# Load top 10 Free Apps
Top10_Apps_Size_Price = Tot_Apps_Size_Price.sort_values(by='Size_MB', ascending=False).head(10)
Top10_Apps_Size_Price
# Out:
#              Size_MB  Price  Count
# 323620  73222.591724  39.99      1
# 323619  55966.684362  29.99      1
# 323618  46456.905587  39.99      1
# 323617  45104.025642  44.99      1
# 323616  43870.335733  49.99      1
# 323615  42760.803113  19.99      1
# 323614  40410.851272  35.99      1
# 323613  40105.749650  39.99      1
# 323612  36724.346972  54.99      1
# 323611  35358.327187  24.99      1

# %%
# Create a Bar Plot to Show the Size in MB's Vs Price of App
sns.barplot(Top10_Apps_Size_Price, x='Size_MB', y='Price', color='blue')
plt.xticks(rotation=45)
plt.title('Top 10 Apps: Size in MB vs Price')
plt.show()

# %% [markdown]
# > **Figure-10A:** Plot Showing the size of the app in MB and its Price.

# %%
# Create a Pairplot to show relation between Free and Paid Apps with the Price
sns.pairplot(df, hue='Type', vars=['Size_MB', 'Price'])
plt.show()
# Out:
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.11/dist-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# ...

# %% [markdown]
# > **Figure-10B:** The Pair-Plot above further highlights the relation of Free and Paid Apps with the Price.

# %% [markdown]
# - **Answer 13:** We tried to find a direct/indirect correlation between the Size of App and its Price. \
#     This implies that the Size of App is irrelevant to the Price of the app (except for few exceptions).

# %% [markdown]
# ---

# %% [markdown]
# **Question 14:** What are the top 10 Apps producing Developers?

# %%
# Group the dataset by Primary_Genre and Type, and Count the Number of Apps in each group
Top10_Cnt_Dev = df.groupby(['Developer']).size().reset_index(name='Count')

# Load the Top 10 Free Apps
Top10_Cnt_App_Dev = Top10_Cnt_Dev.sort_values(by='Count', ascending=False).head(10)

# %%
# Print the top 10 count of App Developers
Top10_Cnt_App_Dev.head(10)
# Out:
#                                        Developer  Count
# 84502                                    ChowNow   3966
# 432773                             Touch2Success   1649
# 21446                      Alexander Velimirovic   1506
# 259262                    MINDBODY, Incorporated   1247
# 331925                                   Phorest   1131
# 309328                OFFLINE MAP TRIP GUIDE LTD   1022
# 262967                              Magzter Inc.    928
# 8456                                   ASK Video    781
# 345604  RAPID ACCELERATION INDIA PRIVATE LIMITED    733
# 306122                  Nonlinear Educating Inc.    555

# %%
# Create a Pie Chart to Show the Top 10 App Producing Developres
plt.figure(figsize=(8,6))
data = Top10_Cnt_App_Dev.groupby('Developer')['Count'].max().sort_values(ascending = True)
data = data.head(10)
labels = data.keys()
plt.pie(data, labels= labels,autopct='%.0f%%') 
plt.title('Top 10 App Producing developer', fontsize=14)
plt.show()

# %% [markdown]
# > **Figure-11:** A pie chart showing which Developer or Company has highest App Development Contribution to the Apple App Store.

# %% [markdown]
# - **Answer 14:**
#     1. ChowNow
#     2. Touch2Success
#     3. Alexander Velimirovic
#     4. MINDBODY, Incorporated
#     5. Phorest
#     6. OFFLINE MAP TRIP GUIDE LTD
#     7. Magzter Inc.
#     8. ASK Video
#     9. RAPID ACCELERATION INDIA PRIVATE LIMITED
#     10. Nonlinear Educating Inc.

# %% [markdown]
# ---

# %% [markdown]
# **Question 15:** Which type of Genre attracted what kind of clients in terms of revenue?

# %%
df.groupby(['Primary_Genre', 'Content_Rating'])['Price'].sum().unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# > **Figure-12:** Shows which genre attracted what kind of Clients in terms of Revenues.

# %% [markdown]
# - **Answer 15:**
# > Few interesting points that needs further analysis and attention. What kind of apps that falls under the category of Business & Utilities and are bought by or for Children.
#
# ### Facts:
# - ⚠️ Caution: The content rating attributes may not always provide reliable information.
# - 🚸 Be Aware: An app rated 9+ could contains inappropriate content, Such as an E-Book with mature themes.

# %%
# Select the rows where Content_Rating is Toddlers and Primary Genre is Business 
toddler_business_df = df[(df['Content_Rating'] == 'Children') & (df['Primary_Genre'] == 'Business')]

# Print the Resulting Dataframe
toddler_business_df.head(5)
# Out:
#                                    App_Id                       App_Name  \
# 1780                  com.kiposlabs.ckbbq                 C & K Barbecue
# 1980                           com.awmm2h  A&W Consulting (MM2H) Sdn Bhd
# 2121  com.bidwrangler.colemanandpatterson                   C&P Auctions
# 2425                com.deliaauctions.bid                D'Elia Auctions
# 2572                        my.com.gkfood             G & K Food Sdn Bhd
#
#                                            AppStore_Url Primary_Genre  \
# 1780  https://apps.apple.com/us/app/c-k-barbecue/id1...      Business
# 1980  https://apps.apple.com/us/app/a-w-consulting-m...      Business
# 2121  https://apps.apple.com/us/app/c-p-auctions/id1...      Business
# 2425  https://apps.apple.com/us/app/delia-auctions/i...      Business
# 2572  https://apps.apple.com/us/app/g-k-food-sdn-bhd...      Business
#
#      Content_Rating  Size_Bytes Required_IOS_Version  \
# ...

# %%
# Select the rows where Content_Rating is Toddlers and Primary_Genre is Utilities
toddler_utility_df = df[(df['Content_Rating'] == 'Children') & (df['Primary_Genre'] == 'Utilities')]

# Print the Resulting Dataframe
toddler_utility_df.head(5)
# Out:
#                                 App_Id                       App_Name  \
# 4904                 com.ar.nbtcactive                    NBTC ACTIVE
# 15914                com.dvcstudiox.nw  Interactive Map for New World
# 33195      br.com.europanet.EuroReader                      EuroClube
# 47854  net.kishonti.gfxbench.metal.osx                 GFXBench Metal
# 47998          com.ruichi.learnflutter                  Flutter_learn
#
#                                             AppStore_Url Primary_Genre  \
# 4904   https://apps.apple.com/us/app/nbtc-active/id13...     Utilities
# 15914  https://apps.apple.com/us/app/interactive-map-...     Utilities
# 33195  https://apps.apple.com/us/app/euroclube/id5524...     Utilities
# 47854  https://apps.apple.com/us/app/gfxbench-metal/i...     Utilities
# 47998  https://apps.apple.com/us/app/flutter-learn/id...     Utilities
#
#       Content_Rating    Size_Bytes Required_IOS_Version  \
# 4904        Children  1.057116e+08                  8.0
# ...

# %% [markdown]
# ---

# %% [markdown]
# **Question 16:** YoY (Year on Year) comparison of Apps per Content_Rating.

# %%
cnt_YoY = df.groupby(['Year_Release', 'Content_Rating', 'Primary_Genre']).size().reset_index(name='Count')
cnt_year_app_Release.head(10).sort_values(by='Count', ascending=False)

cnt_YoY.groupby(['Year_Release', 'Content_Rating'])['Count'].sum().unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# > **Figure-13:** YoY (Year on Year) Engagement of various age groups as categoriesed by Apple App Store.

# %% [markdown]
# - **Answer 16:** Clearly the Kids category is taking the lead. However as pointed out earlier the Content Rating of non-kids app are also rated under Kids categories.

# %% [markdown]
# ---

# %% [markdown]
# **Question 17:** User_Rating Vs Price.

# %%
usr_Rat_Pri = df.groupby(['Average_User_Rating', 'Year_Release'])[['Price']].sum()

# Create a Barplot to Show the User Rating Vs Price 
usr_Rat_Pri.groupby(['Year_Release', 'Average_User_Rating'])['Price'].sum().unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# > **Figure-14:** User Rating Vs Price. The higher the Rating more is the Price of the App.

# %% [markdown]
# - **Answer 17:** The higher the User Rating, the higher the Price of the App.

# %% [markdown]
# ---

# %% [markdown]
# **Question 18:** User_Rating Vs MBytes.

# %%
usr_Rat_MB = df.groupby(['Average_User_Rating', 'Year_Release'])[['Size_MB']].sum()
usr_Rat_MB

# Create a Barplot to Show the User Rating Vs MBytes
usr_Rat_MB.groupby(['Year_Release', 'Average_User_Rating'])['Size_MB'].sum().unstack().plot(kind='bar', stacked=True)
plt.show()

# %% [markdown]
# > **Figure-15:** User Rating Vs App Size in MB's. The higher the rating more is the Size in MB of the App.

# %% [markdown]
# - **Answer 18:** The higher the User Rating, the larger the size in MB of the App.

# %% [markdown]
# ---

# %% [markdown]
# **Question 19:** What are the Best App of Year?

# %%
# Iterate over Year Release than find the Best App of the Year
for year in df['Year_Release'].sort_values().unique():
    print(f"Best App of the year {year} was {df[df['Year_Release'] == year].groupby('App_Name')['Reviews'].mean().nlargest(1).index[0]}")
# Out:
# Best App of the year 2008 was Amazon Shopping
# Best App of the year 2009 was WhatsApp Messenger
# Best App of the year 2010 was Instagram
# Best App of the year 2011 was Spotify New Music and Podcasts
# Best App of the year 2012 was YouTube: Watch, Listen, Stream
# Best App of the year 2013 was DoorDash - Food Delivery
# Best App of the year 2014 was TikTok
# Best App of the year 2015 was Google Classroom
# Best App of the year 2016 was Uber Eats: Food Delivery
# Best App of the year 2017 was Shop: package & order tracker
# Best App of the year 2018 was Happy Color® – Paint by Number
# Best App of the year 2019 was Pandora: Music & Podcasts
# Best App of the year 2020 was Match 3D
# Best App of the year 2021 was Royal Match
# Best App of the year 2022 was Anime HighSchool Summer Sports

# %%
# Create a Bar Plot to Show the Best App of each Year by Highest Reviews
best_apps_per_year = (
    df.loc[df.groupby('Year_Release')['Reviews'].idxmax()][['Year_Release', 'App_Name', 'Reviews']]
    .sort_values('Year_Release')
)

plt.figure(figsize=(12,6))
sns.barplot(data=best_apps_per_year, x='Year_Release', y='Reviews', hue='App_Name', dodge=False)
plt.xticks(rotation=45)
plt.title('Best App of Each Year by Reviews')
plt.ylabel('Number of Reviews')
plt.xlabel('Year')
plt.legend(title='App Name', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %% [markdown]
# > **Figure-16:** Show the Best App of Each Year.

# %% [markdown]
# - **Answer 19:** Best App of Each Year:
#     1. 2008 : Amazon Shopping
#     2. 2009 : WhatsApp Messenger
#     3. 2010 : Instagram
#     4. 2011 : Spotify New Music and Podcasts
#     5. 2012 : YouTube: Watch, Listen, Stream
#     6. 2013 : DoorDash - Food Delivery
#     7. 2014 : TikTok
#     8. 2015 : Google Classroom
#     9. 2016 : Uber Eats: Food Delivery
#     10. 2017 : Shop: package & order tracker
#     11. 2018 : Happy Color® – Paint by Number
#     12. 2019 : Pandora: Music & Podcasts
#     13. 2020 : Match 3D
#     14. 2021 : Royal Match
#     15. 2022 : Anime HighSchool Summer Sports

# %% [markdown]
# ---

# %% [markdown]
# **Question 20:** YoY (Year on Year) break down of top 5 Genre based on App Price.

# %%
# Top 5 Genres based on App Prices.
Rev_per_Genre = df.groupby(['Year_Release', 'Primary_Genre'])[['Price']].sum()

top5_genres = (Rev_per_Genre
                        .sort_values(['Year_Release', 'Price'], ascending=[True, False])
                        .groupby('Year_Release')
                        .head(5))

# Define a Colormap: To present each category with a different color 
cmap = plt.get_cmap('tab20')

# Group by year and Primary Genre, and plot a stacked Bar Chart 
top5_genres.groupby(['Year_Release', 'Primary_Genre'])['Price'].sum().unstack().plot(kind='bar', stacked=True, title="Year on Year break down of top-5 Genre based on App Price", cmap=cmap)

# Customize the Plot
plt.xlabel('Year')
plt.ylabel('Total Price')
plt.legend(title='Primary Genre', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# > **Figure-17:** YoY (Year on Year) break down per Genre based on App Price.

# %% [markdown]
# - **Answer 20:** Clearly Educational Apps contributes more Revenue in terms of App Sales.

# %% [markdown]
# ---

# %% [markdown]
# **Question 21:** What are the top Rated Apps in each Category?

# %%
# Drop duplicates to get Highest Rated Apps per Category
top_category_apps = df[df['Reviews'] >= 50].sort_values('Average_User_Rating', ascending=False).drop_duplicates(subset='Primary_Genre')

# Show relevant Columns
category_top = top_category_apps[['Primary_Genre', 'App_Name', 'Average_User_Rating', 'Reviews']].sort_values(by='Average_User_Rating', ascending=False)
print('Top Rated Apps by Category:')
# Show the top 10 Categories
print(category_top.head(10))
# Out:
# Top Rated Apps by Category:
#                  Primary_Genre                                     App_Name  \
# 10                        Book  AA Audio Companion for Alcoholics Anonymous
# 671419                   Games                    American MahJong Practice
# 494113                Business               MyJobAngel: Job Search, Finder
# 753711                 Weather                      UV Index Now - UVI Mate
# 656306  Magazines & Newspapers                Curio: Curated audio articles
# 688651              Navigation                                Natural Atlas
# 664477                Stickers                               Cthulhu Emojis
# 667819                    News                Cubita Now - Noticias de Cuba
# 662524       Graphics & Design                PicsType : Add Text to Photos
# 457076                 Finance                          Santander Argentina
#
#         Average_User_Rating  Reviews
# 10                        5     1285
# ...

# %% [markdown]
# - **Answer 21:** The top Rated App in each category is the app with the Highest Average User Rating and at least 50 Reviews for its Primary Genre. This ensure only well-rated and Popular Apps are selected as the best in Each Category.

# %% [markdown]
# ---

# %% [markdown]
# **Question 22:** What are the Top Categories by App Count?

# %%
# Top categories by App Count
top_categories = df['Primary_Genre'].value_counts().head(10)
top_categories
# Out:
# Primary_Genre
# Games               193641
# Business            128203
# Education           119114
# Utilities            93937
# Lifestyle            84493
# Food & Drink         72815
# Health & Fitness     60682
# Productivity         59389
# Entertainment        53076
# Shopping             49493
# Name: count, dtype: int64

# %%
# Create a Bar Plot to Show the Top Categories by App Count
plt.figure(figsize=(10, 5))
sns.barplot(x=top_categories.index, y=top_categories.values, palette='viridis')
plt.title('Top 10 App Categories by Number of Apps')
plt.ylabel('Number of Apps')
plt.xlabel('Category')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# > **Figure-18:** Show the Top 10 App Categories by Number of Apps.

# %% [markdown]
# - **Answer 22:** The top categories by app count on the Apple App Store are those with the highest number of published apps:
#     - Games is the top category by App Count.
#     - Other leading categories include Business, Education, Utilities and Lifestyle.

# %% [markdown]
# ---

# %% [markdown]
# **Question 23:** What should be ideal Size of an App?

# %% [markdown]
# - Let's do some Feature Engineering to Create sub categories of Column `Size_Bytes`

# %%
# Create a new column for different Size_Categories
df['size_categories'] = pd.cut(df['Size_MB'], bins = [0, 1, 100, 1000, 10000, 100000], labels=['small', 'medium', 'large', 'very large', 'huge'])

# %%
# Print the Value Counts of column Size_Categories
df['size_categories'].value_counts()
# Out:
# size_categories
# medium        1004602
# large          209094
# small           11496
# very large       4021
# huge               50
# Name: count, dtype: int64

# %%
# Create a Bar Plot to Show the mean of Size Categories and Average User Rating 
df.groupby('size_categories')['Average_User_Rating'].mean().sort_values(ascending=False).head().plot(kind='bar')
plt.show()
# Out:
# /tmp/ipykernel_13/2457355758.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('size_categories')['Average_User_Rating'].mean().sort_values(ascending=False).head().plot(kind='bar')

# %% [markdown]
# > **Figure-19:** Show the Barplot for the mean of Size Categories an Average User Rating.

# %%
# Find top 5 size_categories according to Reviews
df.groupby('size_categories')['Reviews'].mean().sort_values(ascending=False).head()
# Out:
# /tmp/ipykernel_13/405011142.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('size_categories')['Reviews'].mean().sort_values(ascending=False).head()
# size_categories
# very large    3822.381497
# large         3643.337327
# medium         237.599150
# small           24.111517
# huge             0.000000
# Name: Reviews, dtype: float64

# %%
# Use above Data to Plot the Bar Chart
df.groupby('size_categories')['Reviews'].mean().sort_values(ascending=False).head().plot(kind='bar')
plt.show()
# Out:
# /tmp/ipykernel_13/2861277945.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('size_categories')['Reviews'].mean().sort_values(ascending=False).head().plot(kind='bar')

# %% [markdown]
# > **Figure-20:** Show the Average Number of Reviews for Apps across different Size Categories.

# %% [markdown]
# - **Answer 23:** The Ideal size of an app is Small to Medium for Apple App Store. Apps in these categories receive higher average user ratings and more reviews, Showing better user engagement. Keeping App size obtimized improves User Satisfaction and Popularity.

# %% [markdown]
# ---

# %% [markdown]
# **Question 24:** IOS Versions Vs Count of App.

# %%
# Group the dataset by Primary_Genre and Type, and count the Number of Apps in Each Group.
Ver_counts = df.groupby(['Required_IOS_Version']).size().reset_index(name='Count')

# Print the top 10 Versions on the basis of Count Values
top_10_Ver_counts = Ver_counts.sort_values(by='Count', ascending=False).head(10)
top_10_Ver_counts
# Out:
#     Required_IOS_Version   Count
# 92                  11.0  210600
# 240                  9.0  206001
# 1                   10.0  195939
# 225                  8.0  150913
# 113                 12.0   94408
# 137                 13.0   52105
# 214                  7.0   46926
# 203                  6.0   42831
# 116                 12.1   20500
# 248                  9.3   16150

# %%
# Create a Barplot to Show the Top 10 IOS Versions Vs Count of App
sns.barplot(top_10_Ver_counts, x='Required_IOS_Version', y='Count', color='blue')
plt.show()

# %% [markdown]
# > **Figure-21:** Top 10 IOS Versions Vs Count of App

# %% [markdown]
# - **Answer 24:** Most apps on the Apple App Store support IOS Version 11.0 and above. The highest App Count are found for recent IOS Versions, showing developers prioritize compatibility with newer systems. Older IOS Versions have significantly fewer supported Apps.

# %% [markdown]
# ---

# %% [markdown]
# **Question 25:** Interdependency of numeric attributes on each other.

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                          Size_Bytes     Price  DeveloperId  \
# Size_Bytes                 1.000000  0.056322    -0.019650
# Price                      0.056322  1.000000    -0.055477
# DeveloperId               -0.019650 -0.055477     1.000000
# Average_User_Rating        0.048960 -0.010444    -0.121220
# Reviews                    0.011249 -0.001089    -0.018658
# Current_Version_Score      0.048419 -0.010461    -0.121020
# Current_Version_Reviews    0.011249 -0.001089    -0.018658
# Size_MB                    1.000000  0.056322    -0.019650
#
#                          Average_User_Rating   Reviews  Current_Version_Score  \
# Size_Bytes                          0.048960  0.011249               0.048419
# Price                              -0.010444 -0.001089              -0.010461
# DeveloperId                        -0.121220 -0.018658              -0.121020
# Average_User_Rating                 1.000000  0.023513               0.997610
# ...

# %%
# Create a heatmap to Show the Interdependency of Numerica Attributes on Each Other.
plt.figure(figsize=(8, 6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), cbar=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# > **Figure-22:** Displaying the Correlation between the Numerical Attributes of the Dataset.

# %% [markdown]
# - **Answer 25:** Very few attributes have Strong dependencies on each other, except for Average_User_Rating and Current_Version_Score.

# %% [markdown]
# ---

# %% [markdown]
# # 7.0 Summary:
# > The EDA exercise conducted on the Apple App Store dataset has yield numerous interesting insights. The dataset was found to be relatively Clean and Consistent throughout the Analysis. We posed several questions to the Dataset and Provided detailed answers and findings as Follows:
#
# **Q1:** What are the top 10 Categories that are installed from the Apple App Store?\
# **A:** Gaming Apps are the most installed apps from the Apple App Store.
#
# **Q2:** What are the highest top 10 rated Primary_Genre based on Average_User_Rating?\
# **A:** Based on Average_User_Rating the highest top 10 Rated pimary_genre are Weather, Games, Photo & Video, Music, Book, Reference, Finance, Entertainment, Social Networking, Health & Fitness.
#
# **Q3:** Which Primary_Genre has the highest count of Paid and Free apps?\
# **A:** The list of Free Apps includes Games, Business, Education, Utilities and Lifestyle, while the list of Paid Apps includes Education, Games, Utilities, Stickers and Productivity.
#
# **Q4:** What are the top 5 Paid Apps based with highest Ratings?\
# **A:** The top 5 Paid Apps with highest Ratings are AA Big Book and More, Gabe and the Pesky Bug, Aakkospeli Lapsille, F&P Prompting Guide 1, Animal Fun for Toddlers & Kids.
#
# **Q5:** What are the top 5 Free Apps based with highest Ratings?\
# **A:** The top 5 Free Apps based with highest Ratings are AAB Mobile, Sát hạch lái xe ôtô, São Judas - Chama Aqui!, Aalisiri Audiobooks, Aarti Bhajan Chalisa Sangrah.
#
# **Q6:** What are the top 10 most Reviewed Apps (Unique)?\
# **A:** The top 10 Most Reviewed Apps on the Apple App Store are YouTube, Instagram, Spotify New Music and Podcasts, Venmo, DoorDash - Food Delivery, TikTok, Lyft, WhatsApp Messenger, Pandora: Music & Podcasts, Bible.
#
# **Q7:** What are the top 10 Game Apps based on Reviews on the Apple App Store?\
# **A:** The top 10 Game Apps based on Reviews on the Apple App Store are Roblox, Sniper 3D: Gun Shooting Games, Episode - Choose Your Story, Candy Crush Saga, Toon Blast, Happy Color® – Paint by Number, Golf Clash, Hole.io, Clash Royale, Bowmasters - Multiplayer Game.
#
# **Q8:** What are the top 10 Bussiness Apps based on Reviews on the Apple App Store?\
# **A:** The top 10 Business Apps based on Reviews on the Apple App Store are ZOOM Cloud Meetings, Indeed Job Search, ADP Mobile Solutions, Microsoft Teams, DoorDash - Driver, SAP Concur, Scanner App: PDF Document Scan, Adobe Scan: PDF Scanner & OCR, Genius Scan - Document Scanner, USPS Mobile®.
#
# **Q9:** What are the top 10 Education Apps based on Reviews on the Apple App Store?\
# **A:** The top 10 Education Apps based on Reviews on the Apple App Store are Canvas Student, Google Classroom, ClassDojo, Duolingo - Language Lessons, Remind: School Communication, ABCmouse.com, Quizlet: Learn with Flashcards, PictureThis - Plant Identifier, Photomath, Epic - Kids' Books & Reading.
#
# **Q10:** What are the top 10 Social Networking Apps based on Reviews on the Apple App Store?\
# **A:** The top 10 Social Networking Apps based on Reviews on the Apple App Store are WhatsApp Messenger, Marco Polo - Stay in Touch, Discord - Talk, Chat & Hangout, GroupMe, Google Duo, Plenty of Fish Dating, Facebook, Clubhouse, Hoop - Make new friends, Life360: Find Family & Friends.
#
# **Q11:** What are the Apps with highest Content_Rating?\
# **A:** The apps with the highest Content Rating are for Kids, Children, Adults, Teens and Everyone, with a breakdown based on the count of apps under each category.
#
# **Q12:** In which years were the most apps released?\
# **A:** In 2020, the Apple App Store saw the highest number of apps released, likely due to COVID-19 pandemic forcing more people to stay at home during lockdowns.
#
# **Q13:** How does the Size of an App in MB's compare to its Price?\
# **A:** We tried to find a Direct/Indirect correlation between App Size and Price but found that, except for a few exceptions, the Size of the App is irrelevant to the Price.
#
# **Q14:** What are the top 10 Apps producing Developers?\
# **A:** The top 10 App-Producing Developers are ChowNow, Touch2Success, Alexander Velimirovic, MINDBODY-Incorporated, Phorest, OFFLINE MAP TRIP GUIDE LTD, Magzter Inc, ASK Video, RAPID ACCELERATION INDIA PRIVATE LIMITED, and Nonlinear Educating Inc.
#
# **Q15:** Which type of Genre attracted what kind of clients in terms of revenue?\
# **A:** Some interesting points needs further Analysis and Attention, such as What kind of Business & Utilities apps are bought by or for kids and Childrens. It was found that the information stored in the content rating attribute is not very reliable and that there is a possibility that an App is rated for 9+ but is actually an E-Book with Unsuitable topics.
#
# **Q16:** How do app releases per content rating compare Year on Year?\
# **A:** Clearly, the Kid's category is taking the lead, but as pointed out earlier, the Content Rating of Non-Kids App is also rated under the Kid's Category
#
# **Q17:** How does User Rating compare to Price?\
# **A:** The higher the User Rating, the higher the Price of the App.
#
# **Q18:** How does User Rating compare to MB Size?\
# **A:** The higher the User Rating, the larger the Size in MB of the App.
#
# **Q19:** What are the Best App of Year?\
# **A:** The best App of Each Year are given as Follows:
#    1. 2008 : Amazon Shopping
#    2. 2009 : WhatsApp Messenger
#    3. 2010 : Instagram
#    4. 2011 : Spotify New Music and Podcasts
#    5. 2012 : YouTube: Watch, Listen, Stream
#    6. 2013 : DoorDash - Food Delivery
#    7. 2014 : TikTok
#    8. 2015 : Google Classroom
#    9. 2016 : Uber Eats: Food Delivery
#    10. 2017 : Shop: package & order tracker
#    11. 2018 : Happy Color® – Paint by Number
#    12. 2019 : Pandora: Music & Podcasts
#    13. 2020 : Match 3D
#    14. 2021 : Royal Match
#    15. 2022 : Anime HighSchool Summer Sports
#
# **Q20:** How do YoY (Year on Year) breakdowns per Genre based on App Price compare?\
# **A:** Educational Apps contributes more Revenue in terms of App Sales.
#
# **Q21:** What are the top Rated Apps in each Category?\
# **A:** The top Rated App in each category is the app with the Highest Average User Rating and at least 50 Reviews for its Primary Genre. This ensure only well-rated and Popular Apps are selected as the best in Each Category. Here is the list of Top Rated Apps in each Category, where the Categories are on the Left Side and Apps are on the Right Side given as Follows:
#    1. Utilities : SесurеХ VРN - Wifi Proxy
#    2. Book : AA Audio Companion for Alcoholics Anonymous
#    3. Lifestyle : AA Big Book and More
#    4. Productivity : StreamBeing - Voice for Twitch
#    5. Photo & Video : Stop Motion Studio
#    6. Education : KaDa故事-中文儿童早教绘本故事大全
#    7. Reference : Daily Devotional For Women App
#    8. Games : Fallen Hero: Rebirth
#    9. Medical : Daily Inspirational Wisdom Quotes and Sayings
#    10. Entertainment : Hafez Fortunes
#    11. Health & Fitness : I Deserve a Donut
#    12. Navigation : Waterway Guide
#    13. Developer Tools : SNMP & SSH Terminal
#    14. Business : D&D Energy Group
#    15. Finance : C&N Mobile Banking App
#    16. News : Sakshi Epaper
#    17. Food & Drink : Vegan Recipe Book
#    18. Weather : PWS Monitor
#    19. Graphics & Design : My Icon Changer
#    20. Music : Tunable – Tuner & Metronome
#    21. Shopping : D4 Blanks!
#    22. Travel : Asian Lock
#    23. Social Networking : NABA: Protector
#
# **Q22:** What are the top Categories by App Count?\
# **A:** The top categories by app count on the Apple App Store are those with the highest number of published apps:
#     - Games is the top category by App Count.
#     - Other leading categories include Business, Education, Utilities and Lifestyle.
#
# **Q23:** What should be ideal Size of an App?\
# **A:** The Ideal size of an app is Small to Medium for Apple App Store. Apps in these categories receive higher average user ratings and more reviews, Showing better user engagement. Keeping App size obtimized improves User Satisfaction and Popularity.
#
# **Q24:** How does IOS Version compare to Count of App?\
# **A:** Most apps on the Apple App Store support IOS Version 11.0 and above. The highest App Count are found for recent IOS Versions, showing developers prioritize compatibility with newer systems. Older IOS Versions have significantly fewer supported Apps.
#
# **Q25:** Interdependency of numeric attributes on each other.\
# **A:** Very few attributes have Strong dependencies on each other, except for Average_User_Rating and Current_Version_Score.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ### Conclusion & Findings:
#
# > The Primary goal of this Project is to Analyze the Apple App Store dataset and Identify insights based on the Data. By doing So, we aim to project Customer Dynamics and Demands to Developers and Relevant Stakeholders, helping them Generate more Business for their Upcoming Applications.
#
# #### Milestones Achieved:
# - **Data Cleaning:** Successfully handled missing values and removed irrelevant columns, ensuring a cleand and reliable dataset for analysis.
# - **Deduplication:** Verified that no duplicate records exists; Repeated app names represent unique entries with different versions on release dates.
# - **Feature Engineering:** Created new features such as App Size Categories, Review Categories, and App Type (Free/Paid) to enhance Analysis.
# - **Comprehensive EDA:** Explored all Major Attributes, including App Genre, Ratings, Reviews, Price, Content Rating, Release Year, and Developer Information.
#
# #### Key Findings:
# - **Dominance of Gaming Apps:** Games are the most Published and Downloaded Category, followed by Business, Education, Utilities and Lifestyle.
# - **Top-Rated Genres:** Weather, Games, Photo & Video, Music and Book genres have the highest Average User Ratings.
# - **Revenue Insights:** Educational Apps contributes the most Revenue, indicating Strong Demand and Willingness to pay in this segment.
# - **App Size Matters:** Small to Medium-Sized Apps receive Higher User Ratings and more Reviews, showing user Preference for Optimized App Sizes.
# - **Platform Compatibility:** Most apps Support IOS Version 11.0 and above, reflecting Developer's focus on Newer Devices and Operating Systems.
# - **Content Rating Reliability:** Content Rating information is sometimes unreliable; Apps Rated for younger audience may contain inappropriate material.
# - **User Rating & Price Correlation:** Higher Rated Apps tend to be priced higher, suggesting perceived value aligns with user satisfaction.
# - **Developer Activity:** A few Developers, such as CHowNow and Touch2Success, are responsible for a significant number of published Apps.
# - **Yearly Trends:** The Highest Number of App releases occured in 2020, likely influenced by the COVID-19 Pandemic and Increased Digital Engagement.
# - **Best App by Year:** Each year has Standout Apps based on User Reviews, with well-known names like Amazon Shopping, WhatsApp, Instagram and TikTok leadin in their respective Years.
# - **Interdependency of Features:** Most numeric attributes show weak Correlations, except for User Rating and Current Version Score.
#
# #### Overall Impact:
# This Analysis provides actionable insights for Developers and Stakeholders to understand Market Trends, User Perferences and Opportunities for Growth. By focusing on Popular Genres, optimizing App Size and ensuring reliable Content Ratings, Developers can enhance user Satisfaction and Business Sucess on the Apple App Store.
